# %% [markdown]
# ## Importando o cliente

# %%
from core.ckan_api_reader import Ckan

# %%
CKAN_DOMAIN = "https://repositorio.seade.gov.br/api/3/"

# %%
ckan = Ckan(CKAN_DOMAIN)

# %%
ckan.pkgs
# Out:
# {'agricultura-municipal',
#  'anexo-metodologico-populacao',
#  'anexos-metodologicos-seade-municipios',
#  'aprovacao-escolar-por-municipio-ano-nivel-de-ensino-e-rede-de-atendimento',
#  'casamentos',
#  'cnae-20',
#  'codigos-nomes-dos-distritos-do-municipio-de-sao-paulo',
#  'comercio-exterior',
#  'comercio-exterior-nos-municipios',
#  'covid-19',
#  'demografia',
#  'domicilios-estado-de-sao-paulo',
#  'economia',
#  'educacao-basica-painel',
#  'educacao-do-ensino-superior',
#  'emprego-formal-2021-painel',
#  'emprego-formal-ocupacoes',
#  'emprego-rais-e-arquivos-auxiliares',
#  'equipamento',
#  'estabelecimentos-de-saude',
#  'estatisticas-vitais',
#  'estatisticas-vitais-microdados',
#  'ideb',
#  'indice-paulista-de-desenvolvimento-municipal-ipdm',
#  'informacoes-municipais',
#  'infraestrutura-e-meio-ambiente',
#  'leitos-hospitalares-por-municipio-por-ano',
#  'limites-e-regioes',
#  'matriculas-por-municipio-ano-nivel-de-ensino-e-rede-de-atendimento',
# ...

# %% [markdown]
# ## Fazendo download dos dados

# %%
res = ckan('microdados-casamentos', search_string='2021', attr='name', how='contains', as_list=True, extract=True, parser_params={'sep': ';'})

# %%
res
# Out:
#         anoreferencia  codmunreg  dtregistro  dtcasamento  diasemcas tipocas  \
# 0                2021    3550308     9012021      9012021          7       C
# 1                2021    3550308     9012021      9012021          7       C
# 2                2021    3550308     9012021      9012021          7       C
# 3                2021    3550308     9012021      9012021          7       C
# 4                2021    3550308     9012021      9012021          7       C
# ...               ...        ...         ...          ...        ...     ...
# 231689           2021    3515350    20122021     20122021          2       C
# 231690           2021    3515350    22122021     22122021          4       C
# 231691           2021    3537156    10122021     10122021          6       C
# 231692           2021    3537156    11122021     11122021          7       C
# 231693           2021    3537156    11122021     11122021          7       C
#
# ...

# %%
res.to_csv('arquivo.csv', sep=';', index=False)
